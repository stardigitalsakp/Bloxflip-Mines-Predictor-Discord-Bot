# %% [markdown]
# <a href="https://colab.research.google.com/github/stardigitalsakp/Bloxflip-Mines-Predictor-Discord-Bot/blob/main/Vasu_Photo_Enhancer%7BCall_9491064677%7D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DigiRocks Photo Enhancer -  Your Low Quality Images Convert into 4K Ultra HD**
#
# **This Programs Designed By Surya Pawan**
#
# **For Any Quaries**
#
# **Contact: 9491064677**

# %% [markdown]
# # **Announcement**
#
# **అందరికీ నమస్కారం... Program 2 లో Background Cutting కూడా Add చేయడం జరిగింది.. దానిని ఉపయోగించే ముందు ఒకసారి కాల్ చేయగలరు. ఎలా ఉపయోగించాలో జస్ట్ ఒక్క నిమిషంలోనే Explain చేయడం జరుగుతుంది. ... Thanking You ... DigiRocks**

# %% [markdown]
# # ***Program 1  -  DigiRocks Photo Enhancer***

# %% [markdown]
# # **Step 1**

# %%
from datetime import datetime as dt
e_dt = dt(2025, 12, 28)
c_dt = dt.now()
if c_dt > e_dt:
    raise Exception("...........")
# ... rest of your code ...
#@title Click The Play Button and Upload Your Image { display-mode: "form" }
import cv2
import matplotlib.pyplot as plt
import os
import shutil

def display(img1, img2):
    fig = plt.figure(figsize=(25, 10))
    ax1 = fig.add_subplot(1, 2, 1)
    plt.title('Input', fontsize=16)
    ax1.axis('off')
    ax2 = fig.add_subplot(1, 2, 2)
    plt.title('Digirocks', fontsize=16)
    ax2.axis('off')
    ax1.imshow(img1)
    ax2.imshow(img2)

def imread(img_path):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

from IPython.display import clear_output

# %cd /content
# !rm -rf /content/Digirocks
# !git clone https://github.com/sczhou/CodeFormer.git Digirocks
# %cd /content/Digirocks
from datetime import datetime as dt
e_dt = dt(2025, 12, 28)
c_dt = dt.now()
if c_dt > e_dt:
    raise Exception("...........")
# ... rest of your code ...
# Install dependencies
# !pip install -r /content/Digirocks/requirements.txt
from datetime import datetime as dt
e_dt = dt(2025, 12, 28)
c_dt = dt.now()
if c_dt > e_dt:
    raise Exception("..........")
# ... rest of your code ...
# Install basicsr
# !python /content/Digirocks/basicsr/setup.py develop
from datetime import datetime as dt
e_dt = dt(2025, 12, 28)
c_dt = dt.now()
if c_dt > e_dt:
    raise Exception(".........")
# ... rest of your code ...
# Download the pre-trained models
# !python /content/Digirocks/scripts/download_pretrained_models.py facelib
# !python /content/Digirocks/scripts/download_pretrained_models.py CodeFormer
clear_output()
from datetime import datetime
from datetime import datetime as dt
e_dt = dt(2025, 12, 28)
c_dt = dt.now()
if c_dt > e_dt:
    raise Exception(".........")
# ... rest of your code ...
# title Upload single image or bulk images  { display-mode: "form" }
from PIL import Image
import os
import shutil
from google.colab import files
from datetime import datetime
from datetime import datetime as dt
e_dt = dt(2025, 12, 28)
c_dt = dt.now()
if c_dt > e_dt:
    raise Exception("........")
# ... rest of your code ...
#@title Upload single image or bulk images { display-mode: "form" }
from PIL import Image
import os
import shutil
from google.colab import drive
import os
from google.colab import files
keep_images = False #@param {type:"boolean"}
upload_folder = '/content/Digirocks/inputs/user_upload'
# %cd /content/Digirocks
if keep_images:
    pass
else:
    if os.path.isdir(upload_folder):
        shutil.rmtree(upload_folder)
    os.mkdir(upload_folder)

def image_from_drive():
    drive.mount('/content/gdrive',force_remount=True)
    drive_input_folder = "/content/gdrive/MyDrive/upload"
    if os.path.exists(drive_input_folder):
        print("The folder exists.")
    else:
        os.mkdir(drive_input_folder)
    image_extensions = ['.jpg', '.jpeg', '.png'] # Add more extensions if needed
    for filename in os.listdir(drive_input_folder):
        _, extension = os.path.splitext(filename)
        if extension.lower() in image_extensions:
            drive_image_path=os.path.join(drive_input_folder,filename)
            shutil.copy(drive_image_path,upload_folder)

def image_from_device():
    uploaded = files.upload()
    for filename in uploaded.keys():
        dst_path = os.path.join(upload_folder, filename)
        print(f'move {filename} to {dst_path}')
        shutil.move(filename, dst_path)

upload_from = "local device" #@param ["google drive", "local device"] {allow-input: true}
if upload_from == "google drive":
    image_from_drive()
if upload_from == "local device":
    image_from_device()

clear_output()
file_count = len(os.listdir(upload_folder))
if file_count >= 1:
    print("Run next cell")
else:
    print("Please upload an image.")
from datetime import datetime as dt
e_dt = dt(2025, 12, 28)
c_dt = dt.now()
if c_dt > e_dt:
    raise Exception(".........")
# ... rest of your code ...
# Out:
# Run next cell

# %% [markdown]
# # **Step 2**

# %%
#@title Processing and Download Your Output { display-mode: "form" }
# Inference the uploaded images

#@markdown `DIGIROCKS_FIDELITY`: Balance the quality (lower number) and fidelity (higher number)
# you can add '--bg_upsampler realesrgan' to enhance the background
# %cd /content/Digirocks

DIGIROCKS_FIDELITY = 0.99 #@param {type:"slider", min:0, max:1, step:0.01}
#@markdown `BACKGROUND_ENHANCE`: Enhance background image with Real-ESRGAN
BACKGROUND_ENHANCE = True #@param {type:"boolean"}
#@markdown `FACE_UPSAMPLE`: Upsample restored faces for high-resolution AI-created images
FACE_UPSAMPLE = True #@param {type:"boolean"}
if BACKGROUND_ENHANCE:
    if FACE_UPSAMPLE:
        # !python inference_codeformer.py -w $DIGIROCKS_FIDELITY --input_path inputs/user_upload --bg_upsampler realesrgan --face_upsample
    else:
        # !python inference_codeformer.py -w $DIGIROCKS_FIDELITY --input_path inputs/user_upload --bg_upsampler realesrgan
else:
    # !python inference_codeformer.py -w $DIGIROCKS_FIDELITY --input_path inputs/user_upload

clear_output()
print(f"All results are saved in /content/Digirocks/results/user_upload_{DIGIROCKS_FIDELITY}")


#@title download images { display-mode: "form" }
save_a_copy_in_google_drive = False #@param {type:"boolean"}
if save_a_copy_in_google_drive:
    drive.mount('/content/gdrive',force_remount=True)
    drive_save_path = '/content/gdrive/MyDrive/Digirocks_Bulk_Upscale'
    if os.path.exists(drive_save_path):
        pass
    else:
        os.mkdir(drive_save_path)
    clear_output()
    print(f"All images/zip file save at : {drive_save_path}")

import os
import uuid
from google.colab import files
import shutil
def download_single_images():
    global DIGIROCKS_FIDELITY
    download_folder = '/content/download'
    if os.path.exists(download_folder):
        os.system(f'rm -rf {download_folder}')
    os.makedirs(download_folder)
    folder_path = f"/content/Digirocks/results/user_upload_{DIGIROCKS_FIDELITY}/final_results"
    for filename in os.listdir(folder_path):
        original_path = os.path.join(folder_path, filename)
        name, extension = os.path.splitext(filename)
        random_string = str(uuid.uuid4())[:8]
        new_filename = f"{name}_{random_string}{extension}"
        download_path = f"/content/download/{new_filename}"
        if save_a_copy_in_google_drive:
            drive_path=f"{drive_save_path}/{new_filename}"
            shutil.copy(original_path, drive_path)
        shutil.copy(original_path, download_path)

    files.download(download_path)
def download_zip():
    global DIGIROCKS_FIDELITY
    random_string = str(uuid.uuid4())[:5]
    zip_file_name=f"results_{random_string}.zip"
    var1=os.system(f'zip -r {zip_file_name} results/user_upload_{DIGIROCKS_FIDELITY}/final_results')
    if save_a_copy_in_google_drive:
        sour=f"/content/Digirocks/{zip_file_name}"
        dest=f"{drive_save_path}/{zip_file_name}"
        shutil.copy(sour, dest)

    files.download(zip_file_name)

folder_path = f"/content/Digirocks/results/user_upload_{DIGIROCKS_FIDELITY}/final_results"
image_extensions = ['.jpg', '.jpeg', '.png', '.gif', '.bmp'] # Add more extensions if needed
contains_image = False
for filename in os.listdir(folder_path):
    _, extension = os.path.splitext(filename)
    if extension.lower() in image_extensions:
        contains_image = True
        break
download_format = "single file" #@param ["single file", "zip"] {allow-input: true}
if contains_image:
    if download_format == "single file":
        download_single_images()
    if download_format == "zip":
        download_zip()
else:
    print(f"The folder '{folder_path}' does not contain any image files.")
from datetime import datetime as dt
e_dt = dt(2025, 12, 28)
c_dt = dt.now()
if c_dt > e_dt:
    raise Exception(".........")
# ... rest of your code ...
from datetime import datetime as dt
e_dt = dt(2025, 12, 28)
c_dt = dt.now()
if c_dt > e_dt:
    raise Exception(".........")
# ... rest of your code ...
from datetime import datetime as dt
e_dt = dt(2025, 12, 28)
c_dt = dt.now()
if c_dt > e_dt:
    raise Exception(".........")
# ... rest of your code ...
from datetime import datetime as dt
e_dt = dt(2025, 12, 28)
c_dt = dt.now()
if c_dt > e_dt:
    raise Exception(".........")
# ... rest of your code ...
# Out:
# All results are saved in /content/Digirocks/results/user_upload_0.99

# %% [markdown]
# it's your choice
#
#
#    1. ```"single file"``` if you upload Single image Select Single File at Download Format
#
#    2. ```"zip"``` if you upload Two or Above images Select Zip at Download Format

# %% [markdown]
# # **Step 3**

# %%
#@title Visualize the results { display-mode: "form" }
import os
import glob

input_folder = 'inputs/user_upload'
result_folder = f'results/user_upload_{DIGIROCKS_FIDELITY}/final_results'
input_list = sorted(glob.glob(os.path.join(input_folder, '*')))
for input_path in input_list:
    img_input = imread(input_path)
    basename = os.path.splitext(os.path.basename(input_path))[0]
    output_path = os.path.join(result_folder, basename+'.png')
    img_output = imread(output_path) # Read the output image
    display(img_input, img_output) # Display the input and output images

# %% [markdown]
# ---------------------------------------------------

# %% [markdown]
# # **Program 2**

# %% [markdown]
# # **DigiRocks Background Remover**

# %% [markdown]
# ![20.png](data:image/png;base64,...)

# %% [markdown]
# # **Announcement**
#
# **Background Cutting ఉపయోగించే ముందు ఒకసారి కాల్ చేయగలరు. ఎలా ఉపయోగించాలో జస్ట్ ఒక్క నిమిషంలోనే Explain చేయడం జరుగుతుంది. ... Thanking You ... DigiRocks**

# %%
#@title Install DigiRocks
# %cd /content/
# !git clone https://github.com/PramaLLC/BEN2.git
# %cd /content/BEN2
# !wget https://huggingface.co/PramaLLC/BEN2/resolve/main/BEN2_Base.pth
# !wget https://raw.githubusercontent.com/NeuralFalconYT/BEN2-COLAB/refs/heads/main/app.py
# !pip install gradio>=5.9.1
# !pip install click
from IPython.display import clear_output
clear_output()

# %cd /content/BEN2
# !python app.py --share --debug
# Out:
# /content/BEN2
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   _C._set_float32_matmul_precision(precision)
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4317.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
